# %% [markdown]
# # 👥 Gruppenübung 1
#
# Diese Gruppenübung ist die erste von zwei Gruppenübungen in der Lehrveranstalltung Datengewinnung und -analyse. Die finden im vorliegenden Colab-Notebook die Angabe und Codezellen, in denen Sie den vorgegebenen Code implementieren können.
#
# Des weiteren finden Sie im Notebook eine Reihe von Testfällen, mit denen Sie selbst überprüfen können, ob Sie die Beispiele richtig implementiert haben.
#
# Wenn Sie und Ihre Gruppenmitglieder die gefragten Funktionen im Notebook implementiert haben, können Sie das Colab-Notebook (im .ipynb Format) über Moodle abgeben.
#
# Sie können bei dieser Gruppenübung maximal 60 Punkte erreichen:
#
# Beispiel       | Mögliche Punkte
# ---------------|------------------
# Beispiel 1.1   | 10
# Beispiel 1.2   | 10
# Beispiel 1.3   | 10
# Beispiel 2     | 8
# Testfall 2.4   | 2
# Beispiel 3     | 10
# Beispiel 4     | 10
# **Gesamt**     | **60 Punkte**

# %% [markdown]
# ## 👥 Gruppenmitglieder

# %%
# Setzen Sie hier die Namen der Gruppenmitglieder ein:
# Vorname Nachname
# Vorname Nachname
# Vorname Nachname
# Vorname Nachname

# %% [markdown]
# ## ✏️ Beispiel 1
#
# Dieses und die folgenden Bespiele beziehen sich auf die bereits aus der Lehrveranstaltung bekannte [w3schools](https://www.w3schools.com/sql/) Datenbank. Zur Wiederholung finden Sie das Datenbankschema hier grafisch abgebildet:

# %% [markdown]
# <div style="text-align: center">
#   <img src="https://github.com/markusschanta/fhwien-dga-2025/blob/main/slides/assets/2-1-er-w3schools.png?raw=true" alt="drawing" width="500"/>
# </div>

# %% [markdown]
# Der folgende Code dient dazu, eine Datenbankinstanz zu erstellen und mit Datensätzen zu befüllen. Nach der Ausführung des Codes können Sie die Datenbankinstanz über die Variable ```db``` verwenden.

# %%
import os
from urllib.request import urlopen

GITHUB_URL = "https://raw.githubusercontent.com/markusschanta/w3schools-database/refs/heads/master/w3schools.sqllite.sql"
create_sql = urlopen(GITHUB_URL).read().decode()

import sqlite3

try:
  db.close()
except:
  pass

db = sqlite3.connect("file::memory:?cache=shared")

db.executescript(create_sql)
db.commit()

# %% [markdown]
# ### ✏️ Beispiel 1.1
#
# ⭐ **10 Punkte** ⭐ : Schreiben Sie eine SQL-Abfrage, die Ihnen die Produzenten ("Suppliers")  nach der Anzahl von Produkten absteigend sortiert ausgibt. Das Ergebnis der Abfrage soll als pandas Dataframe zurückgegeben und angezeigt werden.

# %%
import pandas as pd

# Fügen Sie hier Ihre Abfrage ein:
SQL = """ SELECT * FROM suppliers """

pd.read_sql_query(SQL, db)

# %% [markdown]
# ### ✏️ Beispiel 1.2
#
# ⭐ **10 Punkte** ⭐ : Schreiben Sie eine SQL-Abfrage, die Ihnen die 10 Bestellungen mit dem größten Bestellwert ausgibt. Es soll zu diesen Bestellungen die ```OrderID``` und der Bestellwert ausgegeben werden.

# %%
# Fügen Sie hier Ihre Abfrage ein:
SQL = """"""

pd.read_sql_query(SQL, db)

# %% [markdown]
# ### ✏️ Beispiel 1.3
#
# ⭐ **10 Punkte** ⭐ : Schreiben Sie eine SQL-Abfrage, die Ihnen die Anzahl der Produkte nach Land des Produzenten ("Suppliers") gruppiert ausgibt. Das Ergebnis der Abfrage soll als pandas Dataframe in der Variable ```supplier_countries``` abgespeichert werden.
#
# Der Dataframe soll aus zwei Spalten (```country``` und ```num_products```) bestehen.

# %%
# Fügen Sie hier Ihre Abfrage ein:
SQL = """"""

supplier_countries = pd.read_sql_query(SQL, db)

supplier_countries

# %% [markdown]
# ## ✏️ Beispiel 2
#
# ⭐ **8 Punkte** ⭐ : Sie arbeiten als Data Analyst im Marketing-Team eines B2B-Unternehmens. Über ein Webformular wurden potenzielle Neukunden (Leads) generiert und deren angegebenes Jahresbudget in einer Datenbank gespeichert.
#
# Da das Webformular keine automatische Prüfung hatte, sind die Daten unzuverlässig ("dirty data"):
#
# * Manche Nutzer haben das Feld leer gelassen (wird als 0 importiert).
# * Manche haben aus Versehen negative Zahlen eingegeben (Tippfehler).
#
# Darüber hinaus sind manche Budgets sind zu klein für Ihr Produkt (unter 1.000 €), andere sind so groß (über 50.000 €), dass sie vom "Enterprise Sales Team" manuell betreut werden müssen und nicht in die automatische Auswertung gehören.
#
# Schreiben Sie eine Python-Funktion mit dem Namen ```filter_zielgruppe```, die eine Liste von Budgets (Zahlen) entgegennimmt, unbrauchbare oder nicht passende Datensätze herausfiltert und eine bereinigte Liste zurückgibt.
#
# Die Regeln für die bereinigte Zielgruppe ("Qualified Leads") lauten:
#
# * Der Wert darf nicht ```0``` sein (fehlende Angabe).
# * Negative Werte müssen ignoriert werden (Datenfehler).
# * Das Budget muss mindestens **1.000 €** und darf maximal **50.000 €** betragen.
#
# Die Funktion soll einen Parameter ```budgets``` akzeptieren (Liste von int oder float) und eine neue gefilterte liste zurückgeben.

# %%
# Fügen Sie hier Ihren Code ein

# %% [markdown]
# ### 💡 Testfälle
#
# Die folgende Funktion ```check_result``` soll Ihnen helfen, ihre Lösung zum Beispiel selbst zu verfizieren. Die Funktion bekommt drei Parameter übergeben:
#
# * ```input```: Einen Eingabewert
# * ```expected_result```: Den erwarteten Rückgabewert der Funktion
# * ```actual_result```: Den tatsächlichen Rückgabewert der Funktion
#
# Je nachdem, ob der tatsächliche Rückgabewert mit dem erwarteten übereinstimmt, gibt die Funktion  ```check_result``` einen anderen Wert über die Ausgabe aus.

# %%
def check_result(i, expected_result, actual_result):
  print("Input: " + str(i))
  print("Expected result: " + str(expected_result))
  print("Actual result: " + str(actual_result))
  if expected_result == actual_result:
    print("✅ OK! (actual result == expected result)")
  else:
    print("❌ ERROR! (actual result != expected result)")

# %% [markdown]
# ### 💡 Testfall 2.1

# %%
input = [5000, 0, 12000, 800, -500, 45000, 0, 100000, 2500]
expected = [5000, 12000, 45000, 2500]
actual = filter_zielgruppe(input)

check_result(input, expected, actual)

# %% [markdown]
# ### 💡 Testfall 2.2

# %%
input = [7000, 2000, 32000, 18000]
expected = [7000, 2000, 32000, 18000]
actual = filter_zielgruppe(input)

check_result(input, expected, actual)

# %% [markdown]
# ### 💡 Testfall 2.3

# %%
input = [7000]
expected = [7000]
actual = filter_zielgruppe(input)

check_result(input, expected, actual)

# %% [markdown]
# ### ✏️ Testfall 2.4
#
# ⭐ **2 Punkte** ⭐ : Definieren Sie hier einen eigenen Testfall analog zu den vorgegebenen Testfällen 1, 2 und 3. Der Testfall sollte die richtige Implementierung der Funktion ```reverse_with_loop``` überprüfen und idealerweise in Bezug auf die anderen Testfälle komplementäre Aspekte abdecken.

# %%
# Fügen Sie hier Testfall 2.4 ein

# %% [markdown]
# ## ✏️ Beispiel 3
#
# ⭐ **10 Punkte** ⭐ : Implementieren Sie die Funktion ```greet_universal``` so, dass die Funktion eine universale Begrüßung für eine eine übergebene Liste von Namen (```names```) zurückliefert:
#
# * Wenn gar keine Liste an Namen oder eine leere Liste an Namen übergeben wird, solle die Begrüßung ```"Hello stranger!"``` lauten.
# * Wenn eine Liste mit einem Namen (z.B. ```["Alice"]```) übergeben wird, solle die Begrüßung ```"Hello Alice!"``` lauten.
# * Wenn eine Liste mit zwei Namen (z.B. ```["Alice", "Bob"]```) übergeben wird, solle die Begrüßung ```"Hello Alice and Bob!"``` lauten.
# * Wenn eine Liste mit drei oder mehr Namen (z.B. ```["Alice", "Bob", "Carl"]```) übergeben wird, solle die Begrüßung ```"Hello Alice, Bob and Carl!"``` lauten.
#
# Im Folgenden finden Sie wieder Testfälle, die Ihnen helfen sollen, ihre Lösung zum Beispiel selbst zu verfizieren.

# %%
# Fügen Sie hier Ihren Code ein

# %% [markdown]
# ### 💡 Testfall 3.1

# %%
input = ["Alice"]
expected = "Hello Alice!"
actual = greet_universal(input)

check_result(input, expected, actual)

# %% [markdown]
# ### 💡 Testfall 3.2

# %%
input = ["Alice", "Bob"]
expected = "Hello Alice and Bob!"
actual = greet_universal(input)

check_result(input, expected, actual)

# %% [markdown]
# ### 💡 Testfall 3.3

# %%
input = ["Alice", "Bob", "Carl"]
expected = "Hello Alice, Bob and Carl!"
actual = greet_universal(input)

check_result(input, expected, actual)

# %% [markdown]
# ## ✏️  Beispiel 4
#
# ⭐ **10 Punkte** ⭐ : Implementieren Sie die Funktion ```counter``` so, dass die Funktion für eine eine übergebene Liste (```l```) ein Dictionary mit den Häufigkeiten der in der Liste ```l``` enthaltenen Elemente zurückliefert: Wenn in der Liste ```l``` ein Element ```"foo"``` genau zwei mal vorkommt, soll das Ergebnis der Funktion ein Dictionary mit dem Schlüssel ```"foo"```, der auf den Wert ```2``` verweist.
#
# Zum Beispiel soll die Funktion ```counter``` für die Liste ```[1, 2, 3, 3, 3]``` das Dictionary ```{1: 1, 2: 1, 3: 3}``` zurückliefern.

# %%
# Fügen Sie hier Ihren Code ein

# %% [markdown]
# ### 💡 Testfall 4.1

# %%
input = [1, 2, 3]
expected = {1: 1, 2: 1, 3: 1}
actual = counter(input)

check_result(input, expected, actual)

# %% [markdown]
# ### 💡 Testfall 4.2

# %%
input = [1, 2, 3, 2 + 1, 4 - 1]
expected = {1: 1, 2: 1, 3: 3}
actual = counter(input)

check_result(input, expected, actual)

# %% [markdown]
# ### 💡 Testfall 4.3

# %%
input = ['foo', 'bar', 'foo', 'baz', 'foo', 'qux']
expected = {'foo': 3, 'bar': 1, 'baz': 1, 'qux': 1}
actual = counter(input)

check_result(input, expected, actual)
